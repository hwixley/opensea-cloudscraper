# %%
import cloudscraper as cs
import bs4
import json
import datetime
import pickle
import os

# %%
scraper = cs.CloudScraper()  # CloudScraper inherits from requests.Session
url = "https://opensea.io/rankings"

soup = bs4.BeautifulSoup(scraper.get(url).text, "html.parser")

# %%
offset = len("window.__wired__=")
script = soup.script.contents[0][offset:]

decoded_script = json.loads(script)["records"]
print(decoded_script)
# Out:
# {'client:root': {'__id': 'client:root', '__typename': '__Root', 'rankings(first:100,sortBy:"SEVEN_DAY_VOLUME")': {'__ref': 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME")'}, '__RankingsPage_rankings_connection(sortBy:"SEVEN_DAY_VOLUME")': {'__ref': 'client:root:__RankingsPage_rankings_connection(sortBy:"SEVEN_DAY_VOLUME")'}}, 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME")': {'__id': 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME")', '__typename': 'CollectionTypeConnection', 'edges': {'__refs': ['client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:0', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:1', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:2', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:3', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:4', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:5', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:6', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:7', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:8', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:9', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:10', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:11', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:12', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:13', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:14', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:15', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:16', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:17', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:18', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:19', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:20', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:21', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:22', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:23', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:24', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:25', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:26', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:27', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:28', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:29', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:30', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:31', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:32', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:33', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:34', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:35', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:36', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:37', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:38', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:39', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:40', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:41', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:42', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:43', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:44', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:45', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:46', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:47', 'client:root:rankings(first:100,sortBy:"SEVEN_DAY_VOLUME"):edges:48', 'client:root:rankings(first:100,sortBy:"SEVEN_D ...

# %%
keys = decoded_script.keys()
count = 0
slugs = {}

for k in keys:
    if (k[-2:] == "==" or len(k) == 28) and "slug" in decoded_script[k].keys():
        count += 1
        slugs[decoded_script[k]["slug"]] = decoded_script[k]
        print(decoded_script[k]["slug"])

print(count)
# Out:
# 3landers
# tubby-cats
# invisiblefriends
# boredapeyachtclub
# mfers
# nft-worlds
# azuki
# catbloxgenesis
# clonex
# mutant-ape-yacht-club
# worldwidewebbland
# snoop-dogg-doggies
# cryptopunks
# starcatchersnft
# rtfkt-mnlth
# edenhorde-official
# doodles-official
# official-clementines-nightmare
# sandbox
# dooggies
# cool-cats-nft
# soulz-monogatari
# karafuru
# adidasoriginals
# mtdz-1
# sunmiya-club-official
# skuxxversepass
# tos-theotherside
# tastybonesxyz
# g-rilla-official
# metroverse
# tales-of-tsuki-genesis
# coolpetsnft
# official-women-tribe
# the-meta-kongz
# acrocalypse
# syltare-official
# decentraland
# degentoonz-collection
# bunny-buddies
# official-toxic-ape
# grayboys
# syltare-dawn-of-east
# pixels-farm
# hero-galaxy-heroes
# coolmans-universe
# kaijumutant
# onchainmonkey
# cosmodinos-omega
# genesisbloodshedbears
# the-crypto-chicks
# infinite-realm-official
# hapeprime
# cyberfrogz
# floppycollection
# nuclear-nerds-of-the-accidental-apocalypse
# midnightbreeze
# byoland
# xmfers
# world-of-women-nft
# bored-ape-kennel-club
# genesis-creepz
# theorbsbybt
# art-blocks
# psychedelics-anonymous-genesis
# alinft-official
# mferchicks
# llamaverse-genesis
# lootrealms
# roborovski-nft
# chain-runners-nft
# multiversevm
# alienfrensnft
# jpeg-cards
# quirkiesoriginals
# kaiju-kingz
# netvrkland
# pixelmongen1
# mecha-melters
# decentral-games-ice
# peopleintheplacetheylove
# sheepfarm
# town-star
# terraforms
# cameo-pass
# deadfellaz
# vrfuturenft
# cyber-factory-2
# deadfrenz-collection
# treeverse
# cryptobatz-by-ozzy-osbourne
# hausphases
# critterzplots
# alphaelementary
# veefriends
# elemental-fang-lijun
# sneaky-vampiress-syndicate
# thehabibiz
# candy-hunters
# lil-heroes-by-edgar-plans
# 100

# %%
now = datetime.datetime.now()
dt_string = now.strftime("%d-%m-%Y_%H-%M-%S")

with open(f"{dt_string}_rankings.pkl", 'wb') as f:
    pickle.dump(slugs, f)

# %%
dt_string
# Out:
# '25-02-2022_11-06-16'

# %%
with open(f"{dt_string}_rankings.pkl", 'rb') as f:
    loaded_file = pickle.load(f)
    print(loaded_file.keys())
# Out:
# dict_keys(['3landers', 'tubby-cats', 'invisiblefriends', 'boredapeyachtclub', 'mfers', 'nft-worlds', 'azuki', 'catbloxgenesis', 'clonex', 'mutant-ape-yacht-club', 'worldwidewebbland', 'snoop-dogg-doggies', 'cryptopunks', 'starcatchersnft', 'rtfkt-mnlth', 'edenhorde-official', 'doodles-official', 'official-clementines-nightmare', 'sandbox', 'dooggies', 'cool-cats-nft', 'soulz-monogatari', 'karafuru', 'adidasoriginals', 'mtdz-1', 'sunmiya-club-official', 'skuxxversepass', 'tos-theotherside', 'tastybonesxyz', 'g-rilla-official', 'metroverse', 'tales-of-tsuki-genesis', 'coolpetsnft', 'official-women-tribe', 'the-meta-kongz', 'acrocalypse', 'syltare-official', 'decentraland', 'degentoonz-collection', 'bunny-buddies', 'official-toxic-ape', 'grayboys', 'syltare-dawn-of-east', 'pixels-farm', 'hero-galaxy-heroes', 'coolmans-universe', 'kaijumutant', 'onchainmonkey', 'cosmodinos-omega', 'genesisbloodshedbears', 'the-crypto-chicks', 'infinite-realm-official', 'hapeprime', 'cyberfrogz', 'floppycollection', 'nuclear-nerds-of-the-accidental-apocalypse', 'midnightbreeze', 'byoland', 'xmfers', 'world-of-women-nft', 'bored-ape-kennel-club', 'genesis-creepz', 'theorbsbybt', 'art-blocks', 'psychedelics-anonymous-genesis', 'alinft-official', 'mferchicks', 'llamaverse-genesis', 'lootrealms', 'roborovski-nft', 'chain-runners-nft', 'multiversevm', 'alienfrensnft', 'jpeg-cards', 'quirkiesoriginals', 'kaiju-kingz', 'netvrkland', 'pixelmongen1', 'mecha-melters', 'decentral-games-ice', 'peopleintheplacetheylove', 'sheepfarm', 'town-star', 'terraforms', 'cameo-pass', 'deadfellaz', 'vrfuturenft', 'cyber-factory-2', 'deadfrenz-collection', 'treeverse', 'cryptobatz-by-ozzy-osbourne', 'hausphases', 'critterzplots', 'alphaelementary', 'veefriends', 'elemental-fang-lijun', 'sneaky-vampiress-syndicate', 'thehabibiz', 'candy-hunters', 'lil-heroes-by-edgar-plans'])
